# %%
#подключаем пандас
import pandas as pd

# %%
#создаем датафрейм
df_data = pd.read_csv('/content/drive/MyDrive/HW_Data Sample (AIC) для итоговой работы (new) - Online Retail.csv')

# %%
#читаем верхние 5 строк
df_data.head()
# Out:
#   InvoiceNo StockCode                     Description  Quantity   InvoiceDate  \
# 0    536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6  12/1/19 8:26
# 1    536367     84879   ASSORTED COLOUR BIRD ORNAMENT        32  12/1/19 8:34
# 2    536367     21755        LOVE BUILDING BLOCK WORD         3  12/1/19 8:34
# 3    536368     22914    BLUE COAT RACK PARIS FASHION         3  12/1/19 8:34
# 4    536373    84406B  CREAM CUPID HEARTS COAT HANGER         8  12/1/19 9:02
#
#   UnitPrice  CustomerID         Country
# 0      3,39     17850.0  United Kingdom
# 1      1,69     13047.0  United Kingdom
# 2      5,95     13047.0  United Kingdom
# 3      4,95     13047.0  United Kingdom
# 4      2,75     17850.0  United Kingdom

# %%
#получаем инфо о датафрейме
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54214 entries, 0 to 54213
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    54214 non-null  object
#  1   StockCode    54214 non-null  object
#  2   Description  54080 non-null  object
#  3   Quantity     54214 non-null  int64
#  4   InvoiceDate  54214 non-null  object
#  5   UnitPrice    54214 non-null  object
#  6   CustomerID   40643 non-null  float64
#  7   Country      54214 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
#описание датафрейма
df_data.describe()
# Out:
#            Quantity    CustomerID
# count  54214.000000  40643.000000
# mean       9.610802  15283.422803
# std       57.358422   1707.982278
# min    -9600.000000  12347.000000
# 25%        1.000000  13969.000000
# 50%        3.000000  15152.000000
# 75%       10.000000  16775.000000
# max     2400.000000  18287.000000

# %%
#пропуски в датафрейме
pd.isna(df_data)
# Out:
#        InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0          False      False        False     False        False      False
# 1          False      False        False     False        False      False
# 2          False      False        False     False        False      False
# 3          False      False        False     False        False      False
# 4          False      False        False     False        False      False
# ...          ...        ...          ...       ...          ...        ...
# 54209      False      False        False     False        False      False
# 54210      False      False        False     False        False      False
# 54211      False      False        False     False        False      False
# 54212      False      False        False     False        False      False
# 54213      False      False        False     False        False      False
#
#        CustomerID  Country
# 0           False    False
# ...

# %%
#Пропуски в количественном выражении
pd.isna(df_data).sum()
# Out:
# InvoiceNo          0
# StockCode          0
# Description      134
# Quantity           0
# InvoiceDate        0
# UnitPrice          0
# CustomerID     13571
# Country            0
# dtype: int64

# %%
#меняем пропуски на 0
df_full_data = df_data.fillna(0)

# %%
df_full_data.head()
# Out:
#   InvoiceNo StockCode                     Description  Quantity   InvoiceDate  \
# 0    536365    84029E  RED WOOLLY HOTTIE WHITE HEART.         6  12/1/19 8:26
# 1    536367     84879   ASSORTED COLOUR BIRD ORNAMENT        32  12/1/19 8:34
# 2    536367     21755        LOVE BUILDING BLOCK WORD         3  12/1/19 8:34
# 3    536368     22914    BLUE COAT RACK PARIS FASHION         3  12/1/19 8:34
# 4    536373    84406B  CREAM CUPID HEARTS COAT HANGER         8  12/1/19 9:02
#
#   UnitPrice  CustomerID         Country
# 0      3,39     17850.0  United Kingdom
# 1      1,69     13047.0  United Kingdom
# 2      5,95     13047.0  United Kingdom
# 3      4,95     13047.0  United Kingdom
# 4      2,75     17850.0  United Kingdom

# %%
#Пропуски в количественном выражении
pd.isna(df_full_data).sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64
